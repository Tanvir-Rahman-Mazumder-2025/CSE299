# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("kidney_disease_dataset.csv")

# %%
df.head()
# Out:
#    Age of the patient  Blood pressure (mm/Hg)  Specific gravity of urine  \
# 0                  54                     167                      1.023
# 1                  42                     127                      1.023
# 2                  38                     148                      1.016
# 3                   7                      98                      1.017
# 4                  67                     174                      1.015
#
#    Albumin in urine  Sugar in urine Red blood cells in urine  \
# 0                 1               4                   normal
# 1                 3               2                   normal
# 2                 0               0                 abnormal
# 3                 4               0                 abnormal
# 4                 1               1                   normal
#
#   Pus cells in urine Pus cell clumps in urine Bacteria in urine  \
# 0           abnormal              not present       not present
# 1             normal              not present           present
# 2             normal              not present       not present
# 3             normal              not present           present
# 4           abnormal              not present       not present
#
#    Random blood glucose level (mg/dl)  ...  Smoking status  \
# 0                                  96  ...             yes
# 1                                  73  ...              no
# 2                                  77  ...              no
# 3                                 225  ...              no
# 4                                 376  ...             yes
#
#    Body Mass Index (BMI)  Physical activity level  \
# 0                   25.3                      low
# 1                   20.6                 moderate
# 2                   38.4                     high
# 3                   24.7                     high
# 4                   17.6                     high
#
#    Duration of diabetes mellitus (years)  Duration of hypertension (years)  \
# 0                                      4                                16
# 1                                      3                                13
# 2                                     11                                23
# 3                                     24                                 3
# 4                                     22                                24
#
#    Cystatin C level  Urinary sediment microscopy results  \
# 0              0.67                               normal
# 1              0.55                             abnormal
# 2              2.37                             abnormal
# 3              2.54                             abnormal
# 4              1.90                               normal
#
#    C-reactive protein (CRP) level Interleukin-6 (IL-6) level      Target
# 0                            4.88                      10.23  No_Disease
# 1                            4.49                      13.11    Low_Risk
# 2                            4.57                      13.27  No_Disease
# 3                            8.57                      12.36  No_Disease
# 4                            6.75                       1.46  No_Disease
#
# [5 rows x 43 columns]

# %%
df.columns
# Out:
# Index(['Age of the patient', 'Blood pressure (mm/Hg)',
#        'Specific gravity of urine', 'Albumin in urine', 'Sugar in urine',
#        'Red blood cells in urine', 'Pus cells in urine',
#        'Pus cell clumps in urine', 'Bacteria in urine',
#        'Random blood glucose level (mg/dl)', 'Blood urea (mg/dl)',
#        'Serum creatinine (mg/dl)', 'Sodium level (mEq/L)',
#        'Potassium level (mEq/L)', 'Hemoglobin level (gms)',
#        'Packed cell volume (%)', 'White blood cell count (cells/cumm)',
#        'Red blood cell count (millions/cumm)', 'Hypertension (yes/no)',
#        'Diabetes mellitus (yes/no)', 'Coronary artery disease (yes/no)',
#        'Appetite (good/poor)', 'Pedal edema (yes/no)', 'Anemia (yes/no)',
#        'Estimated Glomerular Filtration Rate (eGFR)',
#        'Urine protein-to-creatinine ratio', 'Urine output (ml/day)',
#        'Serum albumin level', 'Cholesterol level',
#        'Parathyroid hormone (PTH) level', 'Serum calcium level',
#        'Serum phosphate level', 'Family history of chronic kidney disease',
#        'Smoking status', 'Body Mass Index (BMI)', 'Physical activity level',
#        'Duration of diabetes mellitus (years)',
#        'Duration of hypertension (years)', 'Cystatin C level',
#        'Urinary sediment microscopy results', 'C-reactive protein (CRP) level',
#        'Interleukin-6 (IL-6) level', 'Target'],
#       dtype='object')

# %%
df.shape
# Out:
# (20538, 43)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20538 entries, 0 to 20537
# Data columns (total 43 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Age of the patient                           20538 non-null  int64
#  1   Blood pressure (mm/Hg)                       20538 non-null  int64
#  2   Specific gravity of urine                    20538 non-null  float64
#  3   Albumin in urine                             20538 non-null  int64
#  4   Sugar in urine                               20538 non-null  int64
#  5   Red blood cells in urine                     20538 non-null  object
#  6   Pus cells in urine                           20538 non-null  object
#  7   Pus cell clumps in urine                     20538 non-null  object
#  8   Bacteria in urine                            20538 non-null  object
#  9   Random blood glucose level (mg/dl)           20538 non-null  int64
#  10  Blood urea (mg/dl)                           20538 non-null  float64
#  11  Serum creatinine (mg/dl)                     20538 non-null  float64
#  12  Sodium level (mEq/L)                         20538 non-null  float64
#  13  Potassium level (mEq/L)                      20538 non-null  float64
#  14  Hemoglobin level (gms)                       20538 non-null  float64
#  15  Packed cell volume (%)                       20538 non-null  int64
#  16  White blood cell count (cells/cumm)          20538 non-null  int64
#  17  Red blood cell count (millions/cumm)         20538 non-null  float64
#  18  Hypertension (yes/no)                        20538 non-null  object
#  19  Diabetes mellitus (yes/no)                   20538 non-null  object
#  20  Coronary artery disease (yes/no)             20538 non-null  object
#  21  Appetite (good/poor)                         20538 non-null  object
#  22  Pedal edema (yes/no)                         20538 non-null  object
#  23  Anemia (yes/no)                              20538 non-null  object
#  24  Estimated Glomerular Filtration Rate (eGFR)  20538 non-null  float64
#  25  Urine protein-to-creatinine ratio            20538 non-null  float64
#  26  Urine output (ml/day)                        20538 non-null  int64
#  27  Serum albumin level                          20538 non-null  float64
#  28  Cholesterol level                            20538 non-null  int64
#  29  Parathyroid hormone (PTH) level              20538 non-null  float64
#  30  Serum calcium level                          20538 non-null  float64
#  31  Serum phosphate level                        20538 non-null  float64
#  32  Family history of chronic kidney disease     20538 non-null  object
#  33  Smoking status                               20538 non-null  object
#  34  Body Mass Index (BMI)                        20538 non-null  float64
#  35  Physical activity level                      20538 non-null  object
#  36  Duration of diabetes mellitus (years)        20538 non-null  int64
#  37  Duration of hypertension (years)             20538 non-null  int64
#  38  Cystatin C level                             20538 non-null  float64
#  39  Urinary sediment microscopy results          20538 non-null  object
#  40  C-reactive protein (CRP) level               20538 non-null  float64
#  41  Interleukin-6 (IL-6) level                   20538 non-null  float64
#  42  Target                                       20538 non-null  object
# dtypes: float64(17), int64(11), object(15)
# memory usage: 6.7+ MB

# %%
df.describe()
# Out:
#        Age of the patient  Blood pressure (mm/Hg)  Specific gravity of urine  \
# count        20538.000000            20538.000000               20538.000000
# mean            47.477895              130.352079                   1.015041
# std             24.941947               29.063838                   0.005793
# min              5.000000               80.000000                   1.005000
# 25%             26.000000              105.000000                   1.010000
# 50%             47.000000              131.000000                   1.015000
# 75%             69.000000              156.000000                   1.020000
# max             90.000000              180.000000                   1.025000
#
#        Albumin in urine  Sugar in urine  Random blood glucose level (mg/dl)  \
# count      20538.000000    20538.000000                        20538.000000
# mean           2.501266        2.494595                          284.630295
# std            1.697084        1.701059                          124.633265
# min            0.000000        0.000000                           70.000000
# 25%            1.000000        1.000000                          176.000000
# 50%            3.000000        2.000000                          284.500000
# 75%            4.000000        4.000000                          393.000000
# max            5.000000        5.000000                          500.000000
#
#        Blood urea (mg/dl)  Serum creatinine (mg/dl)  Sodium level (mEq/L)  \
# count        20538.000000              20538.000000          20538.000000
# mean           104.094240                  7.781865            135.076646
# std             55.726482                  4.179925              8.651000
# min              7.002370                  0.500000            120.000613
# 25%             55.864665                  4.200000            127.563468
# 50%            104.401355                  7.780000            135.044974
# 75%            152.480048                 11.430000            142.607311
# max            199.994361                 15.000000            149.999914
#
#        Potassium level (mEq/L)  ...  Cholesterol level  \
# count             20538.000000  ...       20538.000000
# mean                  4.992314  ...         200.236440
# std                   0.871026  ...          57.863374
# min                   3.500005  ...         100.000000
# 25%                   4.229885  ...         150.000000
# 50%                   4.990991  ...         200.000000
# 75%                   5.749899  ...         250.000000
# max                   6.499827  ...         300.000000
#
#        Parathyroid hormone (PTH) level  Serum calcium level  \
# count                     20538.000000         20538.000000
# mean                         40.265400             9.001840
# std                          17.310488             0.867301
# min                          10.000045             7.500000
# 25%                          25.396841             8.250000
# 50%                          40.423386             8.990000
# 75%                          55.272665             9.750000
# max                          69.999871            10.500000
#
#        Serum phosphate level  Body Mass Index (BMI)  \
# count           20538.000000           20538.000000
# mean                4.241157              27.544240
# std                 1.006735               7.221082
# min                 2.500000              15.000000
# 25%                 3.380000              21.300000
# 50%                 4.230000              27.600000
# 75%                 5.110000              33.800000
# max                 6.000000              40.000000
#
#        Duration of diabetes mellitus (years)  \
# count                           20538.000000
# mean                               14.918152
# std                                 8.963722
# min                                 0.000000
# 25%                                 7.000000
# 50%                                15.000000
# 75%                                23.000000
# max                                30.000000
#
#        Duration of hypertension (years)  Cystatin C level  \
# count                      20538.000000      20538.000000
# mean                          14.946879          1.749459
# std                            8.945500          0.718980
# min                            0.000000          0.500000
# 25%                            7.000000          1.130000
# 50%                           15.000000          1.750000
# 75%                           23.000000          2.370000
# max                           30.000000          3.000000
#
#        C-reactive protein (CRP) level  Interleukin-6 (IL-6) level
# count                    20538.000000                20538.000000
# mean                         5.061633                    7.702504
# std                          2.853217                    4.191765
# min                          0.100000                    0.500000
# 25%                          2.600000                    4.050000
# 50%                          5.070000                    7.710000
# 75%                          7.537500                   11.297500
# max                         10.000000                   15.000000
#
# [8 rows x 28 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Age of the patient                             0
# Blood pressure (mm/Hg)                         0
# Specific gravity of urine                      0
# Albumin in urine                               0
# Sugar in urine                                 0
# Red blood cells in urine                       0
# Pus cells in urine                             0
# Pus cell clumps in urine                       0
# Bacteria in urine                              0
# Random blood glucose level (mg/dl)             0
# Blood urea (mg/dl)                             0
# Serum creatinine (mg/dl)                       0
# Sodium level (mEq/L)                           0
# Potassium level (mEq/L)                        0
# Hemoglobin level (gms)                         0
# Packed cell volume (%)                         0
# White blood cell count (cells/cumm)            0
# Red blood cell count (millions/cumm)           0
# Hypertension (yes/no)                          0
# Diabetes mellitus (yes/no)                     0
# Coronary artery disease (yes/no)               0
# Appetite (good/poor)                           0
# Pedal edema (yes/no)                           0
# Anemia (yes/no)                                0
# Estimated Glomerular Filtration Rate (eGFR)    0
# Urine protein-to-creatinine ratio              0
# Urine output (ml/day)                          0
# Serum albumin level                            0
# Cholesterol level                              0
# Parathyroid hormone (PTH) level                0
# Serum calcium level                            0
# Serum phosphate level                          0
# Family history of chronic kidney disease       0
# Smoking status                                 0
# Body Mass Index (BMI)                          0
# Physical activity level                        0
# Duration of diabetes mellitus (years)          0
# Duration of hypertension (years)               0
# Cystatin C level                               0
# Urinary sediment microscopy results            0
# C-reactive protein (CRP) level                 0
# Interleukin-6 (IL-6) level                     0
# Target                                         0
# dtype: int64

# %%
def draw_histograms(df):
    numeric_columns = df.select_dtypes(include='number')
    for col in numeric_columns.columns:
        plt.figure(figsize=(6, 4))
        sns.histplot(df[col], bins=30, kde=True)
        plt.title(f'Histogram of {col}')
        plt.xlabel(col)
        plt.ylabel('count')
        plt.tight_layout()
        plt.show()
draw_histograms(df)

# %%
def draw_boxplots(df):
    numeric_columns = df.select_dtypes(include='number')
    for col in numeric_columns.columns:
        plt.figure(figsize=(6, 5))
        sns.boxplot(df,y=col)
        plt.title(f'Boxplot of {col}')
        plt.ylabel(col)
        plt.tight_layout()
        plt.show()
draw_boxplots(df)

# %%
def plot_categorical_counts(df):
    count_columns = df.select_dtypes(include='object').columns
    for col in count_columns:
        plt.figure(figsize=(8, 4))
        sns.countplot(data=df, x=col,hue=df['Target'])
        plt.title(f'Count Plot of {col}')
        plt.tight_layout()
        plt.show()
plot_categorical_counts(df)

# %%
def get_outliers_iqr(df):
    numeric_columns = df.select_dtypes(include=['int64', 'float64']).columns
    outlier_data = []

    for col in numeric_columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)][col]
        for idx, val in outliers.items():
            outlier_data.append({'Column': col, 'Index': idx, 'Outlier Value': val})

    return pd.DataFrame(outlier_data)


outliers_df = get_outliers_iqr(df)
print(outliers_df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from sklearn.preprocessing import LabelEncoder
def label_encode_object_columns(df, exclude_columns=None, save_path='label_encoders'):
    df_encoded = df.copy()
    label_encoders = {}

    object_columns = df_encoded.select_dtypes(include='object').columns


    if exclude_columns:
        object_columns = [col for col in object_columns if col not in exclude_columns]

    for col in object_columns:
        le = LabelEncoder()
        df_encoded[col] = le.fit_transform(df_encoded[col].astype(str))
        label_encoders[col] = le



    return df_encoded, label_encoders
df_encoded,label_encoder  = label_encode_object_columns(df,exclude_columns=['Target'])

# %%
sns.countplot(x=df["Target"])
plt.figure(figsize=(13,10))

# %%
df['Target'].unique()
# Out:
# array(['No_Disease', 'Low_Risk', 'Moderate_Risk', 'Severe_Disease',
#        'High_Risk'], dtype=object)

# %%
target_mapping = {
    'No_Disease': 0,
    'Low_Risk': 1,
    'Moderate_Risk': 2,
    'Severe_Disease': 3,
    'High_Risk': 4
}

df_encoded['Target'] = df['Target'].map(target_mapping)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
df_encoded
# Out:
#        Age of the patient  Blood pressure (mm/Hg)  Specific gravity of urine  \
# 0                      54                     167                      1.023
# 1                      42                     127                      1.023
# 2                      38                     148                      1.016
# 3                       7                      98                      1.017
# 4                      67                     174                      1.015
# ...                   ...                     ...                        ...
# 20533                  86                     113                      1.008
# 20534                  47                      80                      1.016
# 20535                  89                     178                      1.011
# 20536                  86                     138                      1.009
# 20537                  63                     120                      1.015
#
#        Albumin in urine  Sugar in urine  Red blood cells in urine  \
# 0                     1               4                         1
# 1                     3               2                         1
# 2                     0               0                         0
# 3                     4               0                         0
# 4                     1               1                         1
# ...                 ...             ...                       ...
# 20533                 5               3                         1
# 20534                 3               4                         1
# 20535                 3               5                         0
# 20536                 1               5                         0
# 20537                 4               5                         0
#
#        Pus cells in urine  Pus cell clumps in urine  Bacteria in urine  \
# 0                       0                         0                  0
# 1                       1                         0                  1
# 2                       1                         0                  0
# 3                       1                         0                  1
# 4                       0                         0                  0
# ...                   ...                       ...                ...
# 20533                   0                         0                  0
# 20534                   0                         0                  0
# 20535                   0                         0                  0
# 20536                   1                         0                  1
# 20537                   0                         1                  0
#
#        Random blood glucose level (mg/dl)  Blood urea (mg/dl)  \
# 0                                      96          169.101369
# 1                                      73          183.223479
# 2                                      77          193.141665
# 3                                     225          125.939396
# 4                                     376          197.188600
# ...                                   ...                 ...
# 20533                                 473           63.735109
# 20534                                 477           19.915668
# 20535                                 141          103.471398
# 20536                                 110          166.200259
# 20537                                 256           54.751936
#
#        Serum creatinine (mg/dl)  Sodium level (mEq/L)  \
# 0                          7.55            146.068410
# 1                         13.37            123.501427
# 2                          9.49            149.456527
# 3                         10.98            131.758843
# 4                          3.01            120.912465
# ...                         ...                   ...
# 20533                      6.58            143.517758
# 20534                      7.31            142.965336
# 20535                      2.64            140.329818
# 20536                      5.50            121.231930
# 20537                     13.90            120.946650
#
#        Potassium level (mEq/L)  Hemoglobin level (gms)  \
# 0                     6.272576                    11.8
# 1                     5.611303                     8.2
# 2                     3.965957                    10.1
# 3                     4.980997                    14.0
# 4                     4.097602                    16.1
# ...                        ...                     ...
# 20533                 4.740731                    11.0
# 20534                 4.545014                    10.4
# 20535                 4.385256                    15.1
# 20536                 3.913860                     6.0
# 20537                 6.223618                     7.9
#
#        Packed cell volume (%)  White blood cell count (cells/cumm)  \
# 0                          35                                 5791
# 1                          25                                 5390
# 2                          46                                12098
# 3                          24                                 6747
# 4                          46                                 5759
# ...                       ...                                  ...
# 20533                      32                                 5820
# 20534                      38                                 5638
# 20535                      30                                 9414
# 20536                      48                                 5705
# 20537                      32                                 9663
#
#        Red blood cell count (millions/cumm)  Hypertension (yes/no)  \
# 0                                       5.6                      1
# 1                                       4.6                      0
# 2                                       4.7                      0
# 3                                       4.8                      0
# 4                                       5.7                      0
# ...                                     ...                    ...
# 20533                                   5.1                      1
# 20534                                   4.4                      1
# 20535                                   5.4                      1
# 20536                                   2.7                      1
# 20537                                   5.7                      1
#
#        Diabetes mellitus (yes/no)  Coronary artery disease (yes/no)  \
# 0                               1                                 0
# 1                               1                                 0
# 2                               0                                 1
# 3                               0                                 1
# 4                               0                                 0
# ...                           ...                               ...
# 20533                           1                                 1
# 20534                           1                                 1
# 20535                           1                                 0
# 20536                           0                                 0
# 20537                           0                                 0
#
#        Appetite (good/poor)  Pedal edema (yes/no)  Anemia (yes/no)  \
# 0                         0                     0                0
# 1                         0                     1                1
# 2                         0                     1                0
# 3                         0                     0                1
# 4                         0                     1                1
# ...                     ...                   ...              ...
# 20533                     0                     0                1
# 20534                     0                     0                0
# 20535                     0                     0                0
# 20536                     1                     0                1
# 20537                     1                     1                1
#
#        Estimated Glomerular Filtration Rate (eGFR)  \
# 0                                            71.62
# 1                                            13.93
# 2                                            60.09
# 3                                            31.62
# 4                                            36.61
# ...                                            ...
# 20533                                        80.46
# 20534                                        61.53
# 20535                                        77.17
# 20536                                       105.58
# 20537                                        26.19
#
#        Urine protein-to-creatinine ratio  Urine output (ml/day)  \
# 0                                   2.51                   1397
# 1                                   4.27                   1632
# 2                                   1.56                    889
# 3                                   3.19                   2424
# 4                                   1.23                    893
# ...                                  ...                    ...
# 20533                               1.36                   2659
# 20534                               1.34                   1166
# 20535                               3.60                   1853
# 20536                               0.40                   1760
# 20537                               2.80                   2772
#
#        Serum albumin level  Cholesterol level  \
# 0                     3.23                152
# 1                     3.47                242
# 2                     4.42                103
# 3                     3.44                140
# 4                     4.14                149
# ...                    ...                ...
# 20533                 4.41                230
# 20534                 3.57                299
# 20535                 2.82                236
# 20536                 3.19                128
# 20537                 2.48                127
#
#        Parathyroid hormone (PTH) level  Serum calcium level  \
# 0                            65.078329                 8.71
# 1                            46.030692                10.41
# 2                            26.214653                 9.14
# 3                            11.931283                 9.81
# 4                            34.909936                10.17
# ...                                ...                  ...
# 20533                        59.483377                 8.31
# 20534                        32.527464                 8.99
# 20535                        31.401397                 9.29
# 20536                        68.175519                 8.57
# 20537                        45.901347                 7.65
#
#        Serum phosphate level  Family history of chronic kidney disease  \
# 0                       4.31                                         0
# 1                       5.78                                         1
# 2                       3.66                                         0
# 3                       3.71                                         0
# 4                       4.62                                         0
# ...                      ...                                       ...
# 20533                   3.78                                         1
# 20534                   4.50                                         1
# 20535                   3.12                                         1
# 20536                   2.52                                         1
# 20537                   2.57                                         1
#
#        Smoking status  Body Mass Index (BMI)  Physical activity level  \
# 0                   1                   25.3                        1
# 1                   0                   20.6                        2
# 2                   0                   38.4                        0
# 3                   0                   24.7                        0
# 4                   1                   17.6                        0
# ...               ...                    ...                      ...
# 20533               0                   38.2                        1
# 20534               0                   26.8                        2
# 20535               1                   30.0                        1
# 20536               1                   28.9                        1
# 20537               0                   36.7                        2
#
#        Duration of diabetes mellitus (years)  \
# 0                                          4
# 1                                          3
# 2                                         11
# 3                                         24
# 4                                         22
# ...                                      ...
# 20533                                     25
# 20534                                      3
# 20535                                      6
# 20536                                      0
# 20537                                      3
#
#        Duration of hypertension (years)  Cystatin C level  \
# 0                                    16              0.67
# 1                                    13              0.55
# 2                                    23              2.37
# 3                                     3              2.54
# 4                                    24              1.90
# ...                                 ...               ...
# 20533                                 1              2.77
# 20534                                 7              1.81
# 20535                                25              1.32
# 20536                                21              2.52
# 20537                                28              1.03
#
#        Urinary sediment microscopy results  C-reactive protein (CRP) level  \
# 0                                        1                            4.88
# 1                                        0                            4.49
# 2                                        0                            4.57
# 3                                        0                            8.57
# 4                                        1                            6.75
# ...                                    ...                             ...
# 20533                                    1                            2.45
# 20534                                    1                            4.19
# 20535                                    0                            5.32
# 20536                                    0                            0.61
# 20537                                    1                            7.00
#
#        Interleukin-6 (IL-6) level  Target
# 0                           10.23       0
# 1                           13.11       1
# 2                           13.27       0
# 3                           12.36       0
# 4                            1.46       0
# ...                           ...     ...
# 20533                        9.31       0
# 20534                        3.45       0
# 20535                        8.39       0
# 20536                        9.53       0
# 20537                        2.36       0
#
# [20538 rows x 43 columns]

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20538 entries, 0 to 20537
# Data columns (total 43 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Age of the patient                           20538 non-null  int64
#  1   Blood pressure (mm/Hg)                       20538 non-null  int64
#  2   Specific gravity of urine                    20538 non-null  float64
#  3   Albumin in urine                             20538 non-null  int64
#  4   Sugar in urine                               20538 non-null  int64
#  5   Red blood cells in urine                     20538 non-null  int64
#  6   Pus cells in urine                           20538 non-null  int64
#  7   Pus cell clumps in urine                     20538 non-null  int64
#  8   Bacteria in urine                            20538 non-null  int64
#  9   Random blood glucose level (mg/dl)           20538 non-null  int64
#  10  Blood urea (mg/dl)                           20538 non-null  float64
#  11  Serum creatinine (mg/dl)                     20538 non-null  float64
#  12  Sodium level (mEq/L)                         20538 non-null  float64
#  13  Potassium level (mEq/L)                      20538 non-null  float64
#  14  Hemoglobin level (gms)                       20538 non-null  float64
#  15  Packed cell volume (%)                       20538 non-null  int64
#  16  White blood cell count (cells/cumm)          20538 non-null  int64
#  17  Red blood cell count (millions/cumm)         20538 non-null  float64
#  18  Hypertension (yes/no)                        20538 non-null  int64
#  19  Diabetes mellitus (yes/no)                   20538 non-null  int64
#  20  Coronary artery disease (yes/no)             20538 non-null  int64
#  21  Appetite (good/poor)                         20538 non-null  int64
#  22  Pedal edema (yes/no)                         20538 non-null  int64
#  23  Anemia (yes/no)                              20538 non-null  int64
#  24  Estimated Glomerular Filtration Rate (eGFR)  20538 non-null  float64
#  25  Urine protein-to-creatinine ratio            20538 non-null  float64
#  26  Urine output (ml/day)                        20538 non-null  int64
#  27  Serum albumin level                          20538 non-null  float64
#  28  Cholesterol level                            20538 non-null  int64
#  29  Parathyroid hormone (PTH) level              20538 non-null  float64
#  30  Serum calcium level                          20538 non-null  float64
#  31  Serum phosphate level                        20538 non-null  float64
#  32  Family history of chronic kidney disease     20538 non-null  int64
#  33  Smoking status                               20538 non-null  int64
#  34  Body Mass Index (BMI)                        20538 non-null  float64
#  35  Physical activity level                      20538 non-null  int64
#  36  Duration of diabetes mellitus (years)        20538 non-null  int64
#  37  Duration of hypertension (years)             20538 non-null  int64
#  38  Cystatin C level                             20538 non-null  float64
#  39  Urinary sediment microscopy results          20538 non-null  int64
#  40  C-reactive protein (CRP) level               20538 non-null  float64
#  41  Interleukin-6 (IL-6) level                   20538 non-null  float64
#  42  Target                                       20538 non-null  int64
# dtypes: float64(17), int64(26)
# memory usage: 6.7 MB

# %%
discrete_columns = [
    'Albumin in urine', 'Sugar in urine',
    'Red blood cells in urine', 'Pus cells in urine',
    'Pus cell clumps in urine', 'Bacteria in urine',
    'Hypertension (yes/no)', 'Diabetes mellitus (yes/no)',
    'Coronary artery disease (yes/no)', 'Appetite (good/poor)',
    'Pedal edema (yes/no)', 'Anemia (yes/no)',
    'Family history of chronic kidney disease', 'Smoking status',
    'Physical activity level', 'Urinary sediment microscopy results',
    'Target'
]

# %%
from sklearn.preprocessing import StandardScaler

def apply_standard_scaler(df, discrete_columns):
    df_scaled = df.copy()


    numeric_columns = df.select_dtypes(include='number').columns


    columns_to_scale = [col for col in numeric_columns if col not in discrete_columns]


    scaler = StandardScaler()
    df_scaled[columns_to_scale] = scaler.fit_transform(df_scaled[columns_to_scale])

    return df_scaled, scaler, columns_to_scale
df_scaled, scaler, scaled_columns = apply_standard_scaler(df_encoded, discrete_columns)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
df_scaled.tail(10)
# Out:
#        Age of the patient  Blood pressure (mm/Hg)  Specific gravity of urine  \
# 20528            1.624696                0.297556                  -1.388092
# 20529            0.822815                1.398608                   1.546724
# 20530            0.862909               -0.252969                  -0.697547
# 20531            1.263850                0.538411                  -0.179638
# 20532            0.341686               -0.321785                   1.201452
# 20533            1.544508               -0.597048                  -1.215455
# 20534           -0.019161               -1.732507                   0.165634
# 20535            1.664790                1.639463                  -0.697547
# 20536            1.544508                0.263149                  -1.042819
# 20537            0.622344               -0.356193                  -0.007002
#
#        Albumin in urine  Sugar in urine  Red blood cells in urine  \
# 20528                 0               4                         1
# 20529                 1               3                         1
# 20530                 2               1                         0
# 20531                 1               3                         0
# 20532                 5               5                         0
# 20533                 5               3                         1
# 20534                 3               4                         1
# 20535                 3               5                         0
# 20536                 1               5                         0
# 20537                 4               5                         0
#
#        Pus cells in urine  Pus cell clumps in urine  Bacteria in urine  \
# 20528                   0                         1                  0
# 20529                   0                         0                  0
# 20530                   0                         1                  1
# 20531                   0                         0                  0
# 20532                   1                         0                  1
# 20533                   0                         0                  0
# 20534                   0                         0                  0
# 20535                   0                         0                  0
# 20536                   1                         0                  1
# 20537                   0                         1                  0
#
#        Random blood glucose level (mg/dl)  Blood urea (mg/dl)  \
# 20528                            0.524509            1.430189
# 20529                            0.283797            1.340966
# 20530                           -0.815455           -0.130755
# 20531                            0.909649           -1.282532
# 20532                           -1.577709           -0.140678
# 20533                            1.511429           -0.724254
# 20534                            1.543524           -1.510604
# 20535                           -1.152451           -0.011177
# 20536                           -1.401187            1.114507
# 20537                           -0.229722           -0.885459
#
#        Serum creatinine (mg/dl)  Sodium level (mEq/L)  \
# 20528                 -0.873689             -0.745541
# 20529                 -1.438306              0.339832
# 20530                 -0.966994              0.872742
# 20531                 -1.632094             -1.112399
# 20532                 -1.117718              1.024817
# 20533                 -0.287540              0.975762
# 20534                 -0.112891              0.911904
# 20535                 -1.230163              0.607248
# 20536                 -0.545924             -1.600399
# 20537                  1.463731             -1.633377
#
#        Potassium level (mEq/L)  Hemoglobin level (gms)  \
# 20528                -0.291560                1.084635
# 20529                 0.758220               -0.451553
# 20530                 1.183394                0.012202
# 20531                -0.581234                0.244079
# 20532                 0.627902                1.258543
# 20533                -0.288842               -0.277645
# 20534                -0.513544               -0.451553
# 20535                -0.696963                0.910727
# 20536                -1.238172               -1.726878
# 20537                 1.413659               -1.176169
#
#        Packed cell volume (%)  White blood cell count (cells/cumm)  \
# 20528                0.912365                             0.709119
# 20529                0.816337                            -1.085125
# 20530               -1.296281                             1.453011
# 20531                0.624281                            -0.216294
# 20532               -0.528056                             0.612902
# 20533               -0.528056                            -0.922847
# 20534                0.048112                            -0.975121
# 20535               -0.720112                             0.109410
# 20536                1.008393                            -0.955877
# 20537               -0.528056                             0.180927
#
#        Red blood cell count (millions/cumm)  Hypertension (yes/no)  \
# 20528                             -0.341270                      1
# 20529                              0.153353                      1
# 20530                              0.647976                      1
# 20531                              0.845826                      0
# 20532                             -0.835894                      0
# 20533                              0.845826                      1
# 20534                              0.153353                      1
# 20535                              1.142600                      1
# 20536                             -1.528367                      1
# 20537                              1.439374                      1
#
#        Diabetes mellitus (yes/no)  Coronary artery disease (yes/no)  \
# 20528                           1                                 0
# 20529                           0                                 1
# 20530                           1                                 0
# 20531                           0                                 1
# 20532                           0                                 1
# 20533                           1                                 1
# 20534                           1                                 1
# 20535                           1                                 0
# 20536                           0                                 0
# 20537                           0                                 0
#
#        Appetite (good/poor)  Pedal edema (yes/no)  Anemia (yes/no)  \
# 20528                     0                     1                1
# 20529                     1                     1                1
# 20530                     1                     1                1
# 20531                     0                     1                1
# 20532                     1                     0                1
# 20533                     0                     0                1
# 20534                     0                     0                0
# 20535                     0                     0                0
# 20536                     1                     0                1
# 20537                     1                     1                1
#
#        Estimated Glomerular Filtration Rate (eGFR)  \
# 20528                                     0.127390
# 20529                                     1.309935
# 20530                                     0.116296
# 20531                                    -0.606603
# 20532                                     0.067423
# 20533                                     0.546558
# 20534                                    -0.021028
# 20535                                     0.447913
# 20536                                     1.299741
# 20537                                    -1.080641
#
#        Urine protein-to-creatinine ratio  Urine output (ml/day)  \
# 20528                          -0.071080              -0.246952
# 20529                           0.542331              -1.635779
# 20530                          -0.126130              -0.989034
# 20531                          -1.140617               0.725742
# 20532                           0.738937               0.268383
# 20533                          -0.723812               1.295187
# 20534                          -0.739541              -0.628300
# 20535                           1.037778               0.256788
# 20536                          -1.478779               0.136972
# 20537                           0.408639               1.440769
#
#        Serum albumin level  Cholesterol level  \
# 20528             1.322154           0.963734
# 20529            -1.712994          -1.715055
# 20530             0.130270          -0.453432
# 20531             0.518325           0.220586
# 20532             0.435170           0.548954
# 20533             1.599336           0.514389
# 20534             0.435170           1.706882
# 20535            -0.604264           0.618084
# 20536            -0.091476          -1.248427
# 20537            -1.075474          -1.265710
#
#        Parathyroid hormone (PTH) level  Serum calcium level  \
# 20528                         0.415898            -1.351167
# 20529                         0.497621            -0.913015
# 20530                         1.180756             0.309196
# 20531                        -0.572193             1.335393
# 20532                         1.567933            -0.567106
# 20533                         1.110220            -0.797712
# 20534                        -0.447019            -0.013652
# 20535                        -0.512072             0.332257
# 20536                         1.612363            -0.497924
# 20537                         0.325588            -1.558712
#
#        Serum phosphate level  Family history of chronic kidney disease  \
# 20528               0.783585                                         1
# 20529               0.326651                                         1
# 20530               1.419319                                         1
# 20531              -1.441485                                         1
# 20532              -0.944818                                         1
# 20533              -0.458084                                         1
# 20534               0.257117                                         1
# 20535              -1.113685                                         1
# 20536              -1.709685                                         1
# 20537              -1.660019                                         1
#
#        Smoking status  Body Mass Index (BMI)  Physical activity level  \
# 20528               1               0.921735                        1
# 20529               1               1.614169                        0
# 20530               0              -0.380041                        1
# 20531               1              -1.044777                        1
# 20532               1              -1.238659                        0
# 20533               0               1.475682                        1
# 20534               0              -0.103067                        2
# 20535               1               0.340090                        1
# 20536               1               0.187755                        1
# 20537               0               1.267952                        2
#
#        Duration of diabetes mellitus (years)  \
# 20528                               0.120695
# 20529                              -1.441194
# 20530                               0.566949
# 20531                               1.124766
# 20532                              -1.218067
# 20533                               1.124766
# 20534                              -1.329631
# 20535                              -0.994940
# 20536                              -1.664321
# 20537                              -1.329631
#
#        Duration of hypertension (years)  Cystatin C level  \
# 20528                          0.341311         -1.320596
# 20529                         -0.105852          1.697642
# 20530                          1.571009          0.056388
# 20531                         -0.217643         -1.682228
# 20532                         -1.670923          1.516826
# 20533                         -1.559132          1.419463
# 20534                         -0.888388          0.084206
# 20535                          1.123846         -0.597331
# 20536                          0.676683          1.071740
# 20537                          1.459219         -1.000690
#
#        Urinary sediment microscopy results  C-reactive protein (CRP) level  \
# 20528                                    1                        0.588251
# 20529                                    0                        0.244771
# 20530                                    0                        0.398986
# 20531                                    0                       -1.570768
# 20532                                    1                        0.903692
# 20533                                    1                       -0.915352
# 20534                                    1                       -0.305499
# 20535                                    0                        0.090555
# 20536                                    0                       -1.560254
# 20537                                    1                        0.679379
#
#        Interleukin-6 (IL-6) level  Target
# 20528                   -0.253480       0
# 20529                   -1.331811       0
# 20530                   -1.570380       0
# 20531                    0.734194       1
# 20532                    0.226043       0
# 20533                    0.383498       0
# 20534                   -1.014515       0
# 20535                    0.164015       0
# 20536                    0.435983       0
# 20537                   -1.274555       0

# %%
from scipy.stats import chi2_contingency

alpha = 0.1


cat_features = [
    'Albumin in urine', 'Sugar in urine',
    'Red blood cells in urine', 'Pus cells in urine',
    'Pus cell clumps in urine', 'Bacteria in urine',
    'Hypertension (yes/no)', 'Diabetes mellitus (yes/no)',
    'Coronary artery disease (yes/no)', 'Appetite (good/poor)',
    'Pedal edema (yes/no)', 'Anemia (yes/no)',
    'Family history of chronic kidney disease', 'Smoking status',
    'Physical activity level', 'Urinary sediment microscopy results'
]


chi2_results = {}

for col in cat_features:
    contingency = pd.crosstab(df_scaled[col], df_encoded['Target'])
    chi2_stat, p_val, _, _ = chi2_contingency(contingency)
    decision = 'Reject Null (Keep Feature)' if p_val < alpha else 'Accept Null (Drop Feature)'
    chi2_results[col] = {
        'chi2_statistic': chi2_stat,
        'p_value': p_val,
        'Decision': decision
    }


chi2_df = pd.DataFrame(chi2_results).T
chi2_df = chi2_df.sort_values(by='p_value')

chi2_df
# Out:
#                                          chi2_statistic   p_value  \
# Pus cells in urine                            17.026195   0.00191
# Sugar in urine                                38.485259  0.007721
# Appetite (good/poor)                            9.98401  0.040698
# Albumin in urine                              25.158508  0.195434
# Coronary artery disease (yes/no)               5.765098  0.217391
# Red blood cells in urine                       5.601616  0.230941
# Hypertension (yes/no)                          4.512364  0.341084
# Anemia (yes/no)                                4.208822  0.378482
# Pedal edema (yes/no)                           3.922865  0.416546
# Urinary sediment microscopy results            3.873681  0.423371
# Bacteria in urine                              3.234297  0.519409
# Family history of chronic kidney disease       3.057928  0.548178
# Smoking status                                 1.621802  0.804868
# Physical activity level                        4.088608  0.849042
# Diabetes mellitus (yes/no)                     1.095538   0.89498
# Pus cell clumps in urine                       0.318122  0.988615
#
#                                                             Decision
# Pus cells in urine                        Reject Null (Keep Feature)
# Sugar in urine                            Reject Null (Keep Feature)
# Appetite (good/poor)                      Reject Null (Keep Feature)
# Albumin in urine                          Accept Null (Drop Feature)
# Coronary artery disease (yes/no)          Accept Null (Drop Feature)
# Red blood cells in urine                  Accept Null (Drop Feature)
# Hypertension (yes/no)                     Accept Null (Drop Feature)
# Anemia (yes/no)                           Accept Null (Drop Feature)
# Pedal edema (yes/no)                      Accept Null (Drop Feature)
# Urinary sediment microscopy results       Accept Null (Drop Feature)
# Bacteria in urine                         Accept Null (Drop Feature)
# Family history of chronic kidney disease  Accept Null (Drop Feature)
# Smoking status                            Accept Null (Drop Feature)
# Physical activity level                   Accept Null (Drop Feature)
# Diabetes mellitus (yes/no)                Accept Null (Drop Feature)
# Pus cell clumps in urine                  Accept Null (Drop Feature)

# %%
from sklearn.feature_selection import mutual_info_classif, f_classif



X = df_encoded.drop(columns=['Target'])
y = df_encoded['Target']


mi_scores = mutual_info_classif(X, y, discrete_features='auto', random_state=42)
mi_scores = pd.Series(mi_scores, index=X.columns).sort_values(ascending=False)


f_scores, p_values = f_classif(X, y)
f_scores = pd.Series(f_scores, index=X.columns).sort_values(ascending=False)
p_values = pd.Series(p_values, index=X.columns).sort_values()


print("Top features by Mutual Information:")
print(mi_scores.head(10))


print("\nTop features by ANOVA F-test:")
print(f_scores.head(10))


feature_scores = pd.DataFrame({
    'Mutual Information': mi_scores,
    'ANOVA F-score': f_scores,
    'ANOVA p-value': p_values
}).sort_values(by='Mutual Information', ascending=False)

print("\nCombined feature scores:")
print(feature_scores.head(10))
# Out:
# Top features by Mutual Information:
# Serum phosphate level                    0.005589
# Appetite (good/poor)                     0.005318
# Hypertension (yes/no)                    0.005271
# Sugar in urine                           0.004563
# Pedal edema (yes/no)                     0.004315
# Random blood glucose level (mg/dl)       0.004106
# Duration of diabetes mellitus (years)    0.003833
# C-reactive protein (CRP) level           0.003284
# Blood pressure (mm/Hg)                   0.003018
# Cystatin C level                         0.002901
# dtype: float64
#
# Top features by ANOVA F-test:
# Pus cells in urine                     4.259043
# Appetite (good/poor)                   2.496609
# Sugar in urine                         2.213392
# Serum albumin level                    2.102258
# White blood cell count (cells/cumm)    1.798482
# Specific gravity of urine              1.707506
# Serum creatinine (mg/dl)               1.570144
# Serum phosphate level                  1.497280
# Coronary artery disease (yes/no)       1.441328
# Red blood cells in urine               1.400445
# dtype: float64
#
# Combined feature scores:
#                                        Mutual Information  ANOVA F-score  \
# Serum phosphate level                            0.005589       1.497280
# Appetite (good/poor)                             0.005318       2.496609
# Hypertension (yes/no)                            0.005271       1.128064
# Sugar in urine                                   0.004563       2.213392
# Pedal edema (yes/no)                             0.004315       0.980665
# Random blood glucose level (mg/dl)               0.004106       0.218120
# Duration of diabetes mellitus (years)            0.003833       1.328994
# C-reactive protein (CRP) level                   0.003284       0.577063
# Blood pressure (mm/Hg)                           0.003018       0.589504
# Cystatin C level                                 0.002901       0.938345
#
#                                        ANOVA p-value
# Serum phosphate level                       0.200006
# Appetite (good/poor)                        0.040690
# Hypertension (yes/no)                       0.341129
# Sugar in urine                              0.064905
# Pedal edema (yes/no)                        0.416599
# Random blood glucose level (mg/dl)          0.928472
# Duration of diabetes mellitus (years)       0.256425
# C-reactive protein (CRP) level              0.679270
# Blood pressure (mm/Hg)                      0.670231
# Cystatin C level                            0.440433

# %%
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

def cramers_v(x, y):
    contingency_table = pd.crosstab(x, y)
    chi2, p, dof, expected = chi2_contingency(contingency_table)
    n = contingency_table.sum().sum()
    phi2 = chi2 / n
    r, k = contingency_table.shape
    phi2_corr = max(0, phi2 - ((k-1)*(r-1))/(n-1))
    r_corr = r - ((r-1)**2)/(n-1)
    k_corr = k - ((k-1)**2)/(n-1)
    return np.sqrt(phi2_corr / min((k_corr-1), (r_corr-1)))



cat_features = [
    'Albumin in urine', 'Sugar in urine', 'Red blood cells in urine', 'Pus cells in urine',
    'Pus cell clumps in urine', 'Bacteria in urine', 'Hypertension (yes/no)',
    'Diabetes mellitus (yes/no)', 'Coronary artery disease (yes/no)', 'Appetite (good/poor)',
    'Pedal edema (yes/no)', 'Anemia (yes/no)', 'Family history of chronic kidney disease',
    'Smoking status', 'Physical activity level', 'Urinary sediment microscopy results'
]

cramers_results = {}

for col in cat_features:
    cramers_results[col] = cramers_v(df_encoded[col], df_encoded['Target'])


cramers_df = pd.DataFrame.from_dict(cramers_results, orient='index', columns=['Cramers_V'])
cramers_df = cramers_df.sort_values(by='Cramers_V', ascending=False)

print(cramers_df)
# Out:
#                                           Cramers_V
# Pus cells in urine                         0.025185
# Appetite (good/poor)                       0.017069
# Sugar in urine                             0.015001
# Coronary artery disease (yes/no)           0.009270
# Red blood cells in urine                   0.008830
# Albumin in urine                           0.007924
# Hypertension (yes/no)                      0.004994
# Anemia (yes/no)                            0.003187
# Diabetes mellitus (yes/no)                 0.000000
# Bacteria in urine                          0.000000
# Pus cell clumps in urine                   0.000000
# Pedal edema (yes/no)                       0.000000
# Family history of chronic kidney disease   0.000000
# Smoking status                             0.000000
# Physical activity level                    0.000000
# Urinary sediment microscopy results        0.000000
